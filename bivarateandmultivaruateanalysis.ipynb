# %%
import pandas as pd

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 234       15.53  3.00    Male    Yes  Sat  Dinner     2
# 44        30.40  5.60    Male     No  Sun  Dinner     4
# 64        17.59  2.64    Male     No  Sat  Dinner     3
# 57        26.41  1.50  Female     No  Sat  Dinner     2
# 98        21.01  3.00    Male    Yes  Fri  Dinner     2

# %%
tips.describe
# Out:
# <bound method NDFrame.describe of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
titanic = pd.read_csv('titanic.csv')

# %%
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
iris = sns.load_dataset('iris')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(tips['total_bill'],tips['tip'])
# Out:
# ------------------------------------------------------------------------
# TypeError                              Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 sns.scatterplot(tips['total_bill'],tips['tip'])
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 were given

# %%
sns.scatterplot(x=tips['total_bill'], y=tips['tip'], hue = tips['sex'], style = tips['smoker'], size = tips['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data = tips, x = 'total_bill' , y = 'tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
titanic.head(2)
# Out:
#    pclass  survived                            name     sex      age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1       1         1  Allison, Master. Hudson Trevor    male   0.9167      1
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0      0   24160  211.3375       B5        S    2   NaN
# 1      2  113781  151.5500  C22 C26        S   11   NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON

# %%
sns.barplot(titanic['pclass'], titanic['age'])
# Out:
# ------------------------------------------------------------------------
# TypeError                              Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 sns.barplot(titanic['pclass'], titanic['age'])
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 were given

# %%
sns.barplot(data=titanic, x='pclass', y='age')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.barplot(data=titanic, x='pclass', y='age' , hue = 'sex')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(x = titanic['sex'],y = 
            titanic['age'] , hue = 'survived')
# Out:
# ------------------------------------------------------------------------
# ValueError                             Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 sns.boxplot(x = titanic['sex'],y =
#       2             titanic['age'] , hue = 'survived')
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)
#    1594     legend="auto", ax=None, **kwargs
#    1595 ):
# -> 1597     p = _CategoricalPlotter(
#    1598         data=data,
#    1599         variables=dict(x=x, y=y, hue=hue),
#    1600         order=order,
#    1601         orient=orient,
# ...

# %%
sns.boxplot(data=titanic,
            x='sex',
            y='age',
            hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.distplot(titanic[titanic['survived']==0]['age'])
sns.distplot(titanic[titanic['survived']==1]['age'])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10228\315033905.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['survived']==0]['age'])
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10228\315033905.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
sns.distplot(titanic[titanic['survived']==0]['age'], hist = False)
sns.distplot(titanic[titanic['survived']==1]['age'], hist = False)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10228\4005772051.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['survived']==0]['age'], hist = False)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10228\4005772051.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
s = pd.crosstab(titanic['pclass'], titanic['survived'])

# %%
sns.heatmap(s)
# Out:
# <Axes: xlabel='survived', ylabel='pclass'>

# %%
(titanic.groupby('embarked').mean()['survived']*100)
# Out:
# ------------------------------------------------------------------------
# TypeError                              Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# ...

# %%
sns.clustermap(pd.crosstab(titanic['parch'],titanic['survived']))

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris, hue = 'species')

# %%
flights.groupby('year', as_index=False).sum(numeric_only=True)
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
new = flights.groupby('year', as_index=False).sum(numeric_only=True)

# %%
sns.lineplot(new['year'],new['passengers'])
# Out:
# ------------------------------------------------------------------------
# TypeError                              Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 sns.lineplot(new['year'],new['passengers'])
#
# TypeError: lineplot() takes from 0 to 1 positional arguments but 2 were given

# %%
sns.lineplot(x = new['year'],y = new['passengers'])
# Out:
# <Axes: xlabel='year', ylabel='passengers'>
